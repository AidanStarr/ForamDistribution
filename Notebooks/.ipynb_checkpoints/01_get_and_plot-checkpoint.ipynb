# %% [markdown]
# # 01: Load the dataset and visualize it
#
# ## Intro
# - Using the ForCenS database of sediment surface planktonic foraminifera by Siccha and Kucera
# >  Siccha, M; Kucera, M (2017): ForCenS, a curated database of planktonic foraminifera census counts in marine surface sediment samples. Scientific Data, 4, 170109, https://doi.org/10.1038/sdata.2017.109
# - pull this dataset from Pangaea.de
# - start plotting it
#
# ----

# %%
# Preamble
import numpy as np
import pandas as pd
import xarray as xr
import cartopy as ctpy
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-110-88f0afa4523d> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import xarray as xr
#       5 import cartopy as ctpy
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'xarray'

# %% [markdown]
# ## Pull the dataset
# The data is available at pangaea.de as full or reduced (following the steps in the paper). We'll download the reduced...
#
# > https://doi.org/10.1594/PANGAEA.873570

# %%
df = pd.read_csv('https://store.pangaea.de/Publications//Siccha-Kucera_2017/ForCenS_reduced.txt',sep='\t',header=0) # download data from Pangaea.de repository
df.drop(index=0,inplace=True) # drop the units row - can retrieve later if needed
df.head() # preview data
# Out:
#      Sample    Sample_ID Flag  Device Latitude Longitude Water_depth Ocean  \
# 1  A15-559F  CLIMAP_0001    1  Piston    8.983    51.733        3797   129
# 2   A152-84  CLIMAP_0002    0  Piston  44.3498   -30.267        2750     7
# 3    A157-3  CLIMAP_0004    0  Piston  50.9332    -41.75        4025     7
# 4   A164-13  CLIMAP_0005    1  Piston  35.7167  -67.3333        5103     7
# 5   A164-15  CLIMAP_0006    0  Piston  36.1333  -68.9167        4624     7
#
#   Sample_depth_top Sample_depth_bottom  ...  \
# 1              NaN                 NaN  ...
# 2              NaN                 NaN  ...
# 3              NaN                 NaN  ...
# 4                0                0.01  ...
# 5              NaN                 NaN  ...
#
#   Globorotalia_menardii_&_Globorotalia_tumida  \
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
#
#   Globigerinoides_ruber_&_Globigerinoides_white  \
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
#
#   Turborotalita_humilis_&_Berggrenia_pumilio  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
#
#   Globorotalia_truncatulinoides_dextral_coiling  \
# 1                                           NaN
# 2                                   0.020576132
# 3                                   0.007122507
# 4                                   0.006637168
# 5                                             0
#
#   Globorotalia_truncatulinoides_sinistral_coiling  \
# 1                                             NaN
# 2                                     0.014403292
# 3                                     0.011396011
# 4                                     0.033185841
# 5                                     0.029411765
#
#   Trilobatus_sacculifer_w_sac_chamber Trilobatus_sacculifer_wo_sac_chamber  \
# 1                                   0                          0.019073569
# 2                         0.004115226                                    0
# 3                                   0                          0.001424501
# 4                         0.015486726                          0.064159292
# 5                         0.016042781                          0.024064171
#
#   Turborotalita_quinqueloba_dextral_coiling  \
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#   Turborotalita_quinqueloba_sinistral_coiling unidentified
# 1                                         NaN  0.032697548
# 2                                         NaN  0.041152263
# 3                                         NaN  0.014245014
# 4                                         NaN   0.03539823
# 5                                         NaN  0.026737968
#
# [5 rows x 72 columns]

# %%
# change the datatypes of numeric columns to floating point
for c in df.columns[4:]:
    df[c] = df[c].apply(pd.to_numeric,errors='ignore')
    
df.dtypes # check that worked
# Out:
# Sample                                          object
# Sample_ID                                       object
# Flag                                            object
# Device                                          object
# Latitude                                       float64
#                                                 ...
# Trilobatus_sacculifer_w_sac_chamber            float64
# Trilobatus_sacculifer_wo_sac_chamber           float64
# Turborotalita_quinqueloba_dextral_coiling      float64
# Turborotalita_quinqueloba_sinistral_coiling    float64
# unidentified                                   float64
# Length: 72, dtype: object

# %%
crs = ctpy.crs.EckertI()
# Plot
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1, 1, 1, projection=crs);
ax.add_feature(ctpy.feature.COASTLINE);
dpth = ax.scatter(df.Longitude,df.Latitude,c=df['Water_depth'],transform=ctpy.crs.PlateCarree(),s=10,cmap='viridis_r');
fig.colorbar(dpth,label='Water Depth (m)',pad=0.01,fraction=0.035,orientation='horizontal');
ax.set_title('ForCenS Sample Depths',fontweight='bold');

# %%
crs = ctpy.crs.Robinson()
# Plot
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1, 1, 1, projection=crs)
ax.add_feature(ctpy.feature.COASTLINE)
cc = 'Globorotalia_truncatulinoides_sinistral_coiling'
sc = ax.scatter(df.Longitude,df.Latitude,transform=ctpy.crs.PlateCarree(),s=df[cc]*400,edgecolor='k')
ax.set_global()
ax.set_title('G. truncatulinoides (sin) Relative Abudnance',fontweight='bold');

# %% [markdown]
# ----
# ## Compare to hydrographic data
# - this involves getting WOA data from the WOA website

# %%
# Temperature from WOA18
# get the decadal average on a 5x5 grid
url = 'https://www.ncei.noaa.gov/thredds-ocean/catalog/ncei/woa/temperature/decav/5deg/catalog.html?dataset=ncei/woa/temperature/decav/5deg/woa18_decav_t00_5d.nc'
T = xr.open_dataset(url)
